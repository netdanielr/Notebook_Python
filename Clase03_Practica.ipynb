# %%
import numpy as np

# %%
import pandas as pd

# %%
data_trx = pd.read_csv('C:\datos\FULLSTACK\DS_DepositoPlazoFijo_01_Trx.csv', encoding = 'latin-1')
data_fin = pd.read_csv('C:\datos\FULLSTACK\DS_DepositoPlazoFijo_01_Financiera.csv', encoding = 'latin-1')
data_cli = pd.read_csv('C:\datos\FULLSTACK\DS_DepositoPlazoFijo_01_Cliente.csv', encoding = 'latin-1')
#DS_DepositoPlazoFijo_01_Trx
#DS_DepositoPlazoFijo_01_Financiera.csv
#DS_DepositoPlazoFijo_01_Cliente.csv

# %%
data_cli.shape
# Out:
# (241513, 13)

# %%
### obtner tipos de datos
data_cli.info()
# otra forma
pd.DataFrame(data.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241513 entries, 0 to 241512
# Data columns (total 13 columns):
# ID_SEC                  241513 non-null int64
# TARGET_VTAMOV           241513 non-null int64
# CODSUBSEGMENTO          241513 non-null object
# PERFIL_TACTICO          241308 non-null object
# PERFIL_DIGITAL          241513 non-null object
# FLGSEXO                 241512 non-null object
# TIPESTCIVIL             241513 non-null object
# TIPNIVELEDUCACIONAL     241513 non-null object
# TIPSITUACIONLABORAL     241513 non-null object
# EDAD                    241513 non-null int64
# DEPARTAMENTO            241391 non-null object
# INGRESO_TABLA_BCAPER    238767 non-null float64
# FLG_AFLUENTE            241308 non-null float64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 24.0+ MB
#                             0
# ID_SEC                  int64
# TARGET_VTAMOV           int64
# CODSUBSEGMENTO         object
# PERFIL_TACTICO         object
# ...

# %%
data_cli.describe(include ='all')
# Out:
#                ID_SEC  TARGET_VTAMOV CODSUBSEGMENTO PERFIL_TACTICO  \
# count   241513.000000  241513.000000         241513         241308
# unique            NaN            NaN              4             12
# top               NaN            NaN            M1N        CONSUMO
# freq              NaN            NaN         147625          46490
# mean    120757.000000       0.002252            NaN            NaN
# std      69718.942119       0.047407            NaN            NaN
# min          1.000000       0.000000            NaN            NaN
# 25%      60379.000000       0.000000            NaN            NaN
# 50%     120757.000000       0.000000            NaN            NaN
# 75%     181135.000000       0.000000            NaN            NaN
# max     241513.000000       1.000000            NaN            NaN
#
#        PERFIL_DIGITAL FLGSEXO TIPESTCIVIL TIPNIVELEDUCACIONAL  \
# count          241513  241512      241513              241513
# ...

# %%
data_fin.describe(include ='all')
# Out:
#               ID_SEC     FLG_PASIVO     FLG_ACTIVO  FLG_INVERSION  \
# count  241513.000000  241308.000000  241308.000000  241308.000000
# mean   120757.000000       0.999163       0.647136       0.060367
# std     69718.942119       0.028921       0.477862       0.238166
# min         1.000000       0.000000       0.000000       0.000000
# 25%     60379.000000       1.000000       0.000000       0.000000
# 50%    120757.000000       1.000000       1.000000       0.000000
# 75%    181135.000000       1.000000       1.000000       0.000000
# max    241513.000000       1.000000       1.000000       1.000000
#
#        FLG_PREST_PER         FLG_TC        FLG_HIP  FLG_CTASUELDO  \
# count  241308.000000  241308.000000  241308.000000  241308.000000
# mean        0.197557       0.599184       0.057822       0.504289
# std         0.398157       0.490065       0.233408       0.499983
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
data_trx.describe(include ='all')
# Out:
#               ID_SEC        TRX_VEN        TRX_HBK        TRX_BMO  \
# count  241513.000000  241513.000000  241513.000000  241513.000000
# mean   120757.000000       3.037969      53.061297     118.103787
# std     69718.942119       7.231525     114.792852     170.346322
# min         1.000000       0.000000       0.000000       0.000000
# 25%     60379.000000       0.000000       0.000000       4.000000
# 50%    120757.000000       1.000000      16.000000      67.000000
# 75%    181135.000000       4.000000      69.000000     169.000000
# max    241513.000000     769.000000   16134.000000   14691.000000
#
#              TRX_DIG       TOTALTRX    TRX_DIG_MON  TRX_DIG_NOMON  \
# count  241513.000000  241513.000000  241513.000000  241513.000000
# mean      171.165084     197.750626      23.050697     148.114387
# std       199.824388     208.751420      33.907440     174.506905
# min         0.000000       1.000000       0.000000       0.000000
# ...

# %%
data = pd.merge(data_cli , data_fin, how = "left" , on = "ID_SEC")
data = pd.merge(data , data_trx, how = "left" , on = "ID_SEC")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 241513 entries, 0 to 241512
# Data columns (total 44 columns):
# ID_SEC                  241513 non-null int64
# TARGET_VTAMOV           241513 non-null int64
# CODSUBSEGMENTO          241513 non-null object
# PERFIL_TACTICO          241308 non-null object
# PERFIL_DIGITAL          241513 non-null object
# FLGSEXO                 241512 non-null object
# TIPESTCIVIL             241513 non-null object
# TIPNIVELEDUCACIONAL     241513 non-null object
# TIPSITUACIONLABORAL     241513 non-null object
# EDAD                    241513 non-null int64
# DEPARTAMENTO            241391 non-null object
# INGRESO_TABLA_BCAPER    238767 non-null float64
# FLG_AFLUENTE            241308 non-null float64
# FLG_PASIVO              241308 non-null float64
# FLG_ACTIVO              241308 non-null float64
# FLG_INVERSION           241308 non-null float64
# FLG_PREST_PER           241308 non-null float64
# ...

# %%
data['TARGET_VTAMOV'].value_counts()
# Out:
# 0    240969
# 1       544
# Name: TARGET_VTAMOV, dtype: int64

# %%
data['TARGET_VTAMOV'].value_counts(normalize = True) *100
# Out:
# 0    99.774753
# 1     0.225247
# Name: TARGET_VTAMOV, dtype: float64

# %%
data.describe(include = 'all')
# Out:
#                ID_SEC  TARGET_VTAMOV CODSUBSEGMENTO PERFIL_TACTICO  \
# count   241513.000000  241513.000000         241513         241308
# unique            NaN            NaN              4             12
# top               NaN            NaN            M1N        CONSUMO
# freq              NaN            NaN         147625          46490
# mean    120757.000000       0.002252            NaN            NaN
# std      69718.942119       0.047407            NaN            NaN
# min          1.000000       0.000000            NaN            NaN
# 25%      60379.000000       0.000000            NaN            NaN
# 50%     120757.000000       0.000000            NaN            NaN
# 75%     181135.000000       0.000000            NaN            NaN
# max     241513.000000       1.000000            NaN            NaN
#
#        PERFIL_DIGITAL FLGSEXO TIPESTCIVIL TIPNIVELEDUCACIONAL  \
# count          241513  241512      241513              241513
# ...

# %%
list(data.columns)
# Out:
# ['ID_SEC',
#  'TARGET_VTAMOV',
#  'CODSUBSEGMENTO',
#  'PERFIL_TACTICO',
#  'PERFIL_DIGITAL',
#  'FLGSEXO',
#  'TIPESTCIVIL',
#  'TIPNIVELEDUCACIONAL',
#  'TIPSITUACIONLABORAL',
#  'EDAD',
#  'DEPARTAMENTO',
#  'INGRESO_TABLA_BCAPER',
#  'FLG_AFLUENTE',
#  'FLG_PASIVO',
#  'FLG_ACTIVO',
#  'FLG_INVERSION',
#  'FLG_PREST_PER',
#  'FLG_TC',
#  'FLG_HIP',
#  'FLG_CTASUELDO',
#  'FLG_CTAAHORRO',
#  'FLG_FFMM',
#  'CANT_FAMPROD',
#  'SALDO_PASIVO',
#  'SALDO_ACTIVO',
#  'SALDO_PASIVO_N_6M',
#  'SALDO_PREST_PER',
#  'SALDO_TC',
#  'SALDO_HIP',
#  'SALDO_CTASUELDO',
#  'SALDO_CTAAHORRO',
#  'SALDO_FFMM',
#  'RCC_D_VEH',
#  'RCC_D_HIP',
#  'RCC_D_TC',
#  'RCC_D_TOTAL',
#  'TRX_VEN',
#  'TRX_HBK',
#  'TRX_BMO',
#  'TRX_DIG',
#  'TOTALTRX',
#  'TRX_DIG_MON',
#  'TRX_DIG_NOMON',
#  'TOTALTRX_MON']

# %%
vars_cat_analizar = ['CODSUBSEGMENTO',
'PERFIL_TACTICO',
'PERFIL_DIGITAL',
'FLGSEXO',
'TIPESTCIVIL',
'TIPNIVELEDUCACIONAL',
'TIPSITUACIONLABORAL',
'DEPARTAMENTO',
'FLG_AFLUENTE',
'FLG_PASIVO',
'FLG_ACTIVO',
'FLG_INVERSION',
'FLG_PREST_PER',
'FLG_TC',
'FLG_HIP',
'FLG_CTASUELDO',
'FLG_CTAAHORRO',
'FLG_FFMM']

# %%
var_num = ['EDAD',
'INGRESO_TABLA_BCAPER',
'CANT_FAMPROD',
'SALDO_PASIVO',
'SALDO_ACTIVO',
'SALDO_PASIVO_N_6M',
'SALDO_PREST_PER',
'SALDO_TC',
'SALDO_HIP',
'SALDO_CTASUELDO',
'SALDO_CTAAHORRO',
'SALDO_FFMM',
'RCC_D_VEH',
'RCC_D_HIP',
'RCC_D_TC',
'RCC_D_TOTAL',
'TRX_VEN',
'TRX_HBK',
'TRX_BMO',
'TRX_DIG',
'TOTALTRX',
'TRX_DIG_MON',
'TRX_DIG_NOMON',
'TOTALTRX_MON']

# %%
var='CODSUBSEGMENTO'
for var in vars_cat_analizar:
    print("--------------------------------------------")
    print("Var :", var)
    print(data[var].value_counts(normalize = True)*100)
# Out:
# --------------------------------------------
# Var : CODSUBSEGMENTO
# M1N    61.125074
# X1N    34.085122
# LEN     4.543441
# P1N     0.246364
# Name: CODSUBSEGMENTO, dtype: float64
# --------------------------------------------
# Var : PERFIL_TACTICO
# CONSUMO                     19.265835
# CONSUMO JOVEN               18.289489
# TOP CONSUMO                 16.344672
# JÓVENES ALTO POTENCIAL      13.549074
# EXCLUSIVO ALTO POTENCIAL    12.576044
# EXCLUSIVO                   10.481625
# ENALTA                       3.919058
# BAJOS INGRESOS               2.819219
# SIN INFO                     1.061299
# JUBILADO                     0.958526
# JUBILADO TOP                 0.652278
# ESTUDIANTE                   0.082882
# Name: PERFIL_TACTICO, dtype: float64
# --------------------------------------------
# Var : PERFIL_DIGITAL
# DIG MON      85.796624
# DIG NOMON     9.973790
# NO DIG        4.229586
# Name: PERFIL_DIGITAL, dtype: float64
# ...

# %%
#var='CODSUBSEGMENTO'
for var in vars_cat_analizar:
    print("--------------------------------------------")
    print("Var :", var)
    temp=pd.DataFrame(data.groupby([var])["TARGET_VTAMOV"].mean()*100)
    temp=temp.sort_values("TARGET_VTAMOV" , ascending =False)
    print(temp)
# Out:
# --------------------------------------------
# Var : CODSUBSEGMENTO
#                 TARGET_VTAMOV
# CODSUBSEGMENTO
# LEN                  0.592363
# X1N                  0.318270
# P1N                  0.168067
# M1N                  0.146317
# --------------------------------------------
# Var : PERFIL_TACTICO
#                           TARGET_VTAMOV
# PERFIL_TACTICO
# ENALTA                         0.655599
# ESTUDIANTE                     0.500000
# JÓVENES ALTO POTENCIAL         0.437376
# EXCLUSIVO ALTO POTENCIAL       0.362474
# EXCLUSIVO                      0.237220
# TOP CONSUMO                    0.169874
# CONSUMO JOVEN                  0.104228
# CONSUMO                        0.103248
# JUBILADO                       0.086468
# JUBILADO TOP                   0.063532
# BAJOS INGRESOS                 0.044098
# SIN INFO                       0.000000
# --------------------------------------------
# Var : PERFIL_DIGITAL
#                 TARGET_VTAMOV
# PERFIL_DIGITAL
# ...

# %%
data.head()
# Out:
#    ID_SEC  TARGET_VTAMOV CODSUBSEGMENTO            PERFIL_TACTICO  \
# 0       1              0            X1N                    ENALTA
# 1       2              0            M1N                   CONSUMO
# 2       3              0            X1N  EXCLUSIVO ALTO POTENCIAL
# 3       4              0            X1N                 EXCLUSIVO
# 4       5              0            M1N                   CONSUMO
#
#   PERFIL_DIGITAL FLGSEXO TIPESTCIVIL TIPNIVELEDUCACIONAL TIPSITUACIONLABORAL  \
# 0        DIG MON       M         SOL                 BAC                 DEP
# 1        DIG MON       F         SOL                 LIC                 DEP
# 2        DIG MON       F         CAS                 BAC                 DEP
# 3        DIG MON       F         CAS                 BAC                 NDI
# 4        DIG MON       F         SOL                 TEC                 IND
#
#    EDAD      ...       RCC_D_TC  RCC_D_TOTAL  TRX_VEN  TRX_HBK  TRX_BMO  \
# ...

# %%
## 2.1 Preprocesamiento de datos

# %%
### 2.1. Tratamiento de nulos

# %%
data_2=data.copy()

# %%
data_2.head()
# Out:
#    ID_SEC  TARGET_VTAMOV CODSUBSEGMENTO            PERFIL_TACTICO  \
# 0       1              0            X1N                    ENALTA
# 1       2              0            M1N                   CONSUMO
# 2       3              0            X1N  EXCLUSIVO ALTO POTENCIAL
# 3       4              0            X1N                 EXCLUSIVO
# 4       5              0            M1N                   CONSUMO
#
#   PERFIL_DIGITAL FLGSEXO TIPESTCIVIL TIPNIVELEDUCACIONAL TIPSITUACIONLABORAL  \
# 0        DIG MON       M         SOL                 BAC                 DEP
# 1        DIG MON       F         SOL                 LIC                 DEP
# 2        DIG MON       F         CAS                 BAC                 DEP
# 3        DIG MON       F         CAS                 BAC                 NDI
# 4        DIG MON       F         SOL                 TEC                 IND
#
#    EDAD      ...       RCC_D_TC  RCC_D_TOTAL  TRX_VEN  TRX_HBK  TRX_BMO  \
# ...

# %%
# para saber cuantos nulos hay por campo
vars_null =pd.DataFrame(data_2.isnull().sum()  )

# %%
vars_null[vars_null[0] !=0]
# Out:
#                           0
# PERFIL_TACTICO          205
# FLGSEXO                   1
# DEPARTAMENTO            122
# INGRESO_TABLA_BCAPER   2746
# FLG_AFLUENTE            205
# FLG_PASIVO              205
# FLG_ACTIVO              205
# FLG_INVERSION           205
# FLG_PREST_PER           205
# FLG_TC                  205
# FLG_HIP                 205
# FLG_CTASUELDO           205
# FLG_CTAAHORRO           205
# FLG_FFMM                205
# CANT_FAMPROD            205
# SALDO_PASIVO            205
# SALDO_ACTIVO            205
# SALDO_PASIVO_N_6M       243
# SALDO_PREST_PER         205
# SALDO_TC                205
# SALDO_HIP               205
# SALDO_CTASUELDO         205
# SALDO_CTAAHORRO         205
# SALDO_FFMM              205
# RCC_D_VEH             39852
# RCC_D_HIP             39852
# RCC_D_TC              39852
# RCC_D_TOTAL           39852

# %%
#data['PERFIL_TACTICO'].fillna("" , inplace = True)
#data['FLGSEXO'].fillna("M" , inplace = True)
#data['FLGSEXO'].fillna("M" , inplace = True)
#data['DEPARTAMENTO'].fillna("" , inplace = True)
#data['FLG_AFLUENTE'].fillna("" , inplace = True)
#data['FLG_PASIVO'].fillna("" , inplace = True)
#data['FLG_ACTIVO'].fillna("" , inplace = True)
#data['PERFIL_TACTICO'].fillna("" , inplace = True)
#data['PERFIL_TACTICO'].fillna("" , inplace = True)
#data['PERFIL_TACTICO'].fillna("" , inplace = True)
#data['PERFIL_TACTICO'].fillna("" , inplace = True)
#data['PERFIL_TACTICO'].fillna("" , inplace = True)

# %%
for var in vars_cat_analizar:
    data_2[var].fillna(data_2[var].mode()[0], inplace = True)

# %%
# para saber cuantos nulos hay por campo
vars_null =pd.DataFrame(data_2.isnull().sum()  ) 
vars_null[vars_null[0] !=0]
# Out:
#                           0
# INGRESO_TABLA_BCAPER   2746
# CANT_FAMPROD            205
# SALDO_PASIVO            205
# SALDO_ACTIVO            205
# SALDO_PASIVO_N_6M       243
# SALDO_PREST_PER         205
# SALDO_TC                205
# SALDO_HIP               205
# SALDO_CTASUELDO         205
# SALDO_CTAAHORRO         205
# SALDO_FFMM              205
# RCC_D_VEH             39852
# RCC_D_HIP             39852
# RCC_D_TC              39852
# RCC_D_TOTAL           39852

# %%
# para saber cuantos nulos hay por campos de variables categoricas
vars_null =pd.DataFrame(data_2[vars_cat_analizar].isnull().sum()  ) 
vars_null[vars_null[0] !=0]
# Out:
# Empty DataFrame
# Columns: [0]
# Index: []

# %%
data_2.groupby("CODSUBSEGMENTO")["INGRESO_TABLA_BCAPER"].median()
# Out:
# CODSUBSEGMENTO
# LEN    22860.11625
# M1N     2585.01000
# P1N    15000.00000
# X1N     7392.46250
# Name: INGRESO_TABLA_BCAPER, dtype: float64

# %%
regs_var_nulo = data_2["INGRESO_TABLA_BCAPER"].isnull()

# %%
data_2.loc[(data_2["CODSUBSEGMENTO"] == 'LEN') & regs_var_nulo, "INGRESO_TABLA_BCAPER"] = 22860
data_2.loc[(data_2["CODSUBSEGMENTO"] == 'M1N') & regs_var_nulo, "INGRESO_TABLA_BCAPER"] = 2585
data_2.loc[(data_2["CODSUBSEGMENTO"] == 'P1N') & regs_var_nulo, "INGRESO_TABLA_BCAPER"] = 15000
data_2.loc[(data_2["CODSUBSEGMENTO"] == 'X1N') & regs_var_nulo, "INGRESO_TABLA_BCAPER"] = 7392

# %%
#d=data_2.groupby(["CODSUBSEGMENTO"] )["INGRESO_TABLA_BCAPER"].median()

# %%
#d.loc[(data_2["CODSUBSEGMENTO"] =='LEN'),"INGRESO_TABLA_BCAPER"]

# %%
### 2.2 Transformando variables categoricas a numericas

# %%
#PERFIL DIGITAL
#'dicc_temp = ('DIG')
list(data_2.PERFIL_DIGITAL.unique())
# Out:
# ['DIG MON', 'DIG NOMON', 'NO DIG']

# %%
dicc_temp = {'DIG MON' : 1, 'DIG NOMON' : 2, 'NO DIG' : 3}

# %%
data_2["PERFIL_DIGITAL"] = data_2["PERFIL_DIGITAL"].map(dicc_temp)

# %%
data_2.head()
# Out:
#    ID_SEC  TARGET_VTAMOV CODSUBSEGMENTO            PERFIL_TACTICO  \
# 0       1              0            X1N                    ENALTA
# 1       2              0            M1N                   CONSUMO
# 2       3              0            X1N  EXCLUSIVO ALTO POTENCIAL
# 3       4              0            X1N                 EXCLUSIVO
# 4       5              0            M1N                   CONSUMO
#
#    PERFIL_DIGITAL FLGSEXO TIPESTCIVIL TIPNIVELEDUCACIONAL TIPSITUACIONLABORAL  \
# 0               1       M         SOL                 BAC                 DEP
# 1               1       F         SOL                 LIC                 DEP
# 2               1       F         CAS                 BAC                 DEP
# 3               1       F         CAS                 BAC                 NDI
# 4               1       F         SOL                 TEC                 IND
#
#    EDAD      ...       RCC_D_TC  RCC_D_TOTAL  TRX_VEN  TRX_HBK  TRX_BMO  \
# ...

# %%
list(data_2.TIPNIVELEDUCACIONAL.unique())
# Out:
# ['BAC',
#  'LIC',
#  'TEC',
#  'MAE',
#  'TIT',
#  'SUP',
#  'SEC',
#  'NDI',
#  'TEI',
#  'DOC',
#  'FAR',
#  'PRI',
#  'ANA']

# %%
dicc_niv_edu ={'BAC' : 6,
 'LIC' : 6,
 'TEC' : 4,
 'MAE' : 8,
 'TIT' : 7,
 'SUP' : 5,
 'SEC' : 3,
 'NDI' : 0,
 'TEI' : 4,
 'DOC' : 9,
 'FAR' : 4,
 'PRI' : 2,
 'ANA' : 1}

# %%
data_2["TIPNIVELEDUCACIONAL"] = data_2["TIPNIVELEDUCACIONAL"].map(dicc_niv_edu)

# %%
data_2.head()
# Out:
#    ID_SEC  TARGET_VTAMOV CODSUBSEGMENTO            PERFIL_TACTICO  \
# 0       1              0            X1N                    ENALTA
# 1       2              0            M1N                   CONSUMO
# 2       3              0            X1N  EXCLUSIVO ALTO POTENCIAL
# 3       4              0            X1N                 EXCLUSIVO
# 4       5              0            M1N                   CONSUMO
#
#    PERFIL_DIGITAL FLGSEXO TIPESTCIVIL  TIPNIVELEDUCACIONAL  \
# 0               1       M         SOL                    6
# 1               1       F         SOL                    6
# 2               1       F         CAS                    6
# 3               1       F         CAS                    6
# 4               1       F         SOL                    4
#
#   TIPSITUACIONLABORAL  EDAD      ...       RCC_D_TC  RCC_D_TOTAL  TRX_VEN  \
# 0                 DEP    37      ...       40428.78   1247875.94        6
# ...

# %%
### Convertir a dummies

# %%
list_temp = ['CODSUBSEGMENTO',
'PERFIL_TACTICO',
'TIPESTCIVIL',
'TIPSITUACIONLABORAL',
'DEPARTAMENTO']

# %%
for var in list_temp:
    df_dummies = pd.get_dummies(data_2[var], prefix = var)
    del data_2[var]
    data_2 = pd.concat([data_2,df_dummies], axis = 1)

# %%
data_2.head()
# Out:
#    ID_SEC  TARGET_VTAMOV  PERFIL_DIGITAL FLGSEXO  TIPNIVELEDUCACIONAL  EDAD  \
# 0       1              0               1       M                    6    37
# 1       2              0               1       F                    6    38
# 2       3              0               1       F                    6    43
# 3       4              0               1       F                    6    43
# 4       5              0               1       F                    4    42
#
#    INGRESO_TABLA_BCAPER  FLG_AFLUENTE  FLG_PASIVO  FLG_ACTIVO  \
# 0          27558.547500           1.0         1.0         1.0
# 1           2769.067500           0.0         1.0         1.0
# 2           9914.747500           1.0         1.0         0.0
# 3           7448.005000           1.0         1.0         1.0
# 4           1203.646313           0.0         1.0         0.0
#
#                     ...                    \
# 0                   ...
# 1                   ...
# 2                   ...
# ...

# %%
data_2.columns
# Out:
# Index(['ID_SEC', 'TARGET_VTAMOV', 'PERFIL_DIGITAL', 'FLGSEXO',
#        'TIPNIVELEDUCACIONAL', 'EDAD', 'INGRESO_TABLA_BCAPER', 'FLG_AFLUENTE',
#        'FLG_PASIVO', 'FLG_ACTIVO', 'FLG_INVERSION', 'FLG_PREST_PER', 'FLG_TC',
#        'FLG_HIP', 'FLG_CTASUELDO', 'FLG_CTAAHORRO', 'FLG_FFMM', 'CANT_FAMPROD',
#        'SALDO_PASIVO', 'SALDO_ACTIVO', 'SALDO_PASIVO_N_6M', 'SALDO_PREST_PER',
#        'SALDO_TC', 'SALDO_HIP', 'SALDO_CTASUELDO', 'SALDO_CTAAHORRO',
#        'SALDO_FFMM', 'RCC_D_VEH', 'RCC_D_HIP', 'RCC_D_TC', 'RCC_D_TOTAL',
#        'TRX_VEN', 'TRX_HBK', 'TRX_BMO', 'TRX_DIG', 'TOTALTRX', 'TRX_DIG_MON',
#        'TRX_DIG_NOMON', 'TOTALTRX_MON', 'CODSUBSEGMENTO_LEN',
#        'CODSUBSEGMENTO_M1N', 'CODSUBSEGMENTO_P1N', 'CODSUBSEGMENTO_X1N',
#        'PERFIL_TACTICO_BAJOS INGRESOS', 'PERFIL_TACTICO_CONSUMO',
#        'PERFIL_TACTICO_CONSUMO JOVEN', 'PERFIL_TACTICO_ENALTA',
#        'PERFIL_TACTICO_ESTUDIANTE', 'PERFIL_TACTICO_EXCLUSIVO',
# ...

# %%
data_2.head()
# Out:
#    ID_SEC  TARGET_VTAMOV  PERFIL_DIGITAL FLGSEXO  TIPNIVELEDUCACIONAL  EDAD  \
# 0       1              0               1       M                    6    37
# 1       2              0               1       F                    6    38
# 2       3              0               1       F                    6    43
# 3       4              0               1       F                    6    43
# 4       5              0               1       F                    4    42
#
#    INGRESO_TABLA_BCAPER  FLG_AFLUENTE  FLG_PASIVO  FLG_ACTIVO  \
# 0          27558.547500           1.0         1.0         1.0
# 1           2769.067500           0.0         1.0         1.0
# 2           9914.747500           1.0         1.0         0.0
# 3           7448.005000           1.0         1.0         1.0
# 4           1203.646313           0.0         1.0         0.0
#
#                     ...                    \
# 0                   ...
# 1                   ...
# 2                   ...
# ...

# %%
dicc_sexo = {'M' : 1, 'F' : 0}

# %%
data_2["FLGSEXO"] = data_2["FLGSEXO"].map(dicc_sexo)

# %%
data_2.head()
# Out:
#    ID_SEC  TARGET_VTAMOV  PERFIL_DIGITAL  FLGSEXO  TIPNIVELEDUCACIONAL  EDAD  \
# 0       1              0               1        1                    6    37
# 1       2              0               1        0                    6    38
# 2       3              0               1        0                    6    43
# 3       4              0               1        0                    6    43
# 4       5              0               1        0                    4    42
#
#    INGRESO_TABLA_BCAPER  FLG_AFLUENTE  FLG_PASIVO  FLG_ACTIVO  \
# 0          27558.547500           1.0         1.0         1.0
# 1           2769.067500           0.0         1.0         1.0
# 2           9914.747500           1.0         1.0         0.0
# 3           7448.005000           1.0         1.0         1.0
# 4           1203.646313           0.0         1.0         0.0
#
#                     ...                    \
# 0                   ...
# 1                   ...
# 2                   ...
# ...

# %%
### revisando nulos en variables numericas
data_2[var_num].isnull().sum()v
# Out:
# EDAD                        0
# INGRESO_TABLA_BCAPER        0
# CANT_FAMPROD              205
# SALDO_PASIVO              205
# SALDO_ACTIVO              205
# SALDO_PASIVO_N_6M         243
# SALDO_PREST_PER           205
# SALDO_TC                  205
# SALDO_HIP                 205
# SALDO_CTASUELDO           205
# SALDO_CTAAHORRO           205
# SALDO_FFMM                205
# RCC_D_VEH               39852
# RCC_D_HIP               39852
# RCC_D_TC                39852
# RCC_D_TOTAL             39852
# TRX_VEN                     0
# TRX_HBK                     0
# TRX_BMO                     0
# TRX_DIG                     0
# TOTALTRX                    0
# TRX_DIG_MON                 0
# TRX_DIG_NOMON               0
# TOTALTRX_MON                0
# dtype: int64

# %%
var_num
# Out:
# ['EDAD',
#  'INGRESO_TABLA_BCAPER',
#  'CANT_FAMPROD',
#  'SALDO_PASIVO',
#  'SALDO_ACTIVO',
#  'SALDO_PASIVO_N_6M',
#  'SALDO_PREST_PER',
#  'SALDO_TC',
#  'SALDO_HIP',
#  'SALDO_CTASUELDO',
#  'SALDO_CTAAHORRO',
#  'SALDO_FFMM',
#  'RCC_D_VEH',
#  'RCC_D_HIP',
#  'RCC_D_TC',
#  'RCC_D_TOTAL',
#  'TRX_VEN',
#  'TRX_HBK',
#  'TRX_BMO',
#  'TRX_DIG',
#  'TOTALTRX',
#  'TRX_DIG_MON',
#  'TRX_DIG_NOMON',
#  'TOTALTRX_MON']

# %%
data_2.head()
# Out:
#    ID_SEC  TARGET_VTAMOV  PERFIL_DIGITAL  FLGSEXO  TIPNIVELEDUCACIONAL  EDAD  \
# 0       1              0               1        1                    6    37
# 1       2              0               1        0                    6    38
# 2       3              0               1        0                    6    43
# 3       4              0               1        0                    6    43
# 4       5              0               1        0                    4    42
#
#    INGRESO_TABLA_BCAPER  FLG_AFLUENTE  FLG_PASIVO  FLG_ACTIVO  \
# 0          27558.547500           1.0         1.0         1.0
# 1           2769.067500           0.0         1.0         1.0
# 2           9914.747500           1.0         1.0         0.0
# 3           7448.005000           1.0         1.0         1.0
# 4           1203.646313           0.0         1.0         0.0
#
#                     ...                    \
# 0                   ...
# 1                   ...
# 2                   ...
# ...

# %%
## revisando nulos en variables numericas
data_2[var_num].isnull().sum()
# Out:
# EDAD                        0
# INGRESO_TABLA_BCAPER        0
# CANT_FAMPROD              205
# SALDO_PASIVO              205
# SALDO_ACTIVO              205
# SALDO_PASIVO_N_6M         243
# SALDO_PREST_PER           205
# SALDO_TC                  205
# SALDO_HIP                 205
# SALDO_CTASUELDO           205
# SALDO_CTAAHORRO           205
# SALDO_FFMM                205
# RCC_D_VEH               39852
# RCC_D_HIP               39852
# RCC_D_TC                39852
# RCC_D_TOTAL             39852
# TRX_VEN                     0
# TRX_HBK                     0
# TRX_BMO                     0
# TRX_DIG                     0
# TOTALTRX                    0
# TRX_DIG_MON                 0
# TRX_DIG_NOMON               0
# TOTALTRX_MON                0
# dtype: int64

# %%
data3=data_2.copy()

# %%
data3[var_num].isnull().sum()
# Out:
# EDAD                        0
# INGRESO_TABLA_BCAPER        0
# CANT_FAMPROD              205
# SALDO_PASIVO              205
# SALDO_ACTIVO              205
# SALDO_PASIVO_N_6M         243
# SALDO_PREST_PER           205
# SALDO_TC                  205
# SALDO_HIP                 205
# SALDO_CTASUELDO           205
# SALDO_CTAAHORRO           205
# SALDO_FFMM                205
# RCC_D_VEH               39852
# RCC_D_HIP               39852
# RCC_D_TC                39852
# RCC_D_TOTAL             39852
# TRX_VEN                     0
# TRX_HBK                     0
# TRX_BMO                     0
# TRX_DIG                     0
# TOTALTRX                    0
# TRX_DIG_MON                 0
# TRX_DIG_NOMON               0
# TOTALTRX_MON                0
# dtype: int64

# %%
data3[var_num] = data3[var_num].fillna(0)

# %%
data3[var_num]
# Out:
#         EDAD  INGRESO_TABLA_BCAPER  CANT_FAMPROD  SALDO_PASIVO  SALDO_ACTIVO  \
# 0         37          27558.547500           3.0      31452.54     899985.87
# 1         38           2769.067500           2.0        473.53       5404.24
# 2         43           9914.747500           2.0      13226.50          0.00
# 3         43           7448.005000           3.0       3290.89      51161.70
# 4         42           1203.646313           1.0         32.76          0.00
# 5         50           9051.270000           2.0       5637.68          0.00
# 6         51           2794.500000           4.0       2420.29      55340.90
# 7         60          12000.000000           3.0       4540.57      88356.09
# 8         42           4951.550000           3.0      13954.82          0.00
# 9         40           1398.182500           2.0         29.01          0.00
# 10        42          12544.680000           1.0        672.71          0.00
# ...

# %%
data_2[var_num] = data_2[var_num].fillna(0)

# %%
data_2[var_num].isnull().sum()
# Out:
# EDAD                    0
# INGRESO_TABLA_BCAPER    0
# CANT_FAMPROD            0
# SALDO_PASIVO            0
# SALDO_ACTIVO            0
# SALDO_PASIVO_N_6M       0
# SALDO_PREST_PER         0
# SALDO_TC                0
# SALDO_HIP               0
# SALDO_CTASUELDO         0
# SALDO_CTAAHORRO         0
# SALDO_FFMM              0
# RCC_D_VEH               0
# RCC_D_HIP               0
# RCC_D_TC                0
# RCC_D_TOTAL             0
# TRX_VEN                 0
# TRX_HBK                 0
# TRX_BMO                 0
# TRX_DIG                 0
# TOTALTRX                0
# TRX_DIG_MON             0
# TRX_DIG_NOMON           0
# TOTALTRX_MON            0
# dtype: int64

# %%
data_2.head()
# Out:
#    ID_SEC  TARGET_VTAMOV  PERFIL_DIGITAL  FLGSEXO  TIPNIVELEDUCACIONAL  EDAD  \
# 0       1              0               1        1                    6    37
# 1       2              0               1        0                    6    38
# 2       3              0               1        0                    6    43
# 3       4              0               1        0                    6    43
# 4       5              0               1        0                    4    42
#
#    INGRESO_TABLA_BCAPER  FLG_AFLUENTE  FLG_PASIVO  FLG_ACTIVO  \
# 0          27558.547500           1.0         1.0         1.0
# 1           2769.067500           0.0         1.0         1.0
# 2           9914.747500           1.0         1.0         0.0
# 3           7448.005000           1.0         1.0         1.0
# 4           1203.646313           0.0         1.0         0.0
#
#                     ...                    \
# 0                   ...
# 1                   ...
# 2                   ...
# ...
